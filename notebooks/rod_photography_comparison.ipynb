# %% [markdown]
# # Plot $z$ vs $z_{old}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep

# %%
hep.style.use("CMS")

# %%
z_AC = [
    2.59,
    0.79,
    0.43,
    2.69,
    0.35,
    0.33,
    1.92,
    1.86,
    1.09,
    1.08,
    0.82,
    0.30,
    0.57,
    2.35,
    2.19,
    0.29,
    0.34,
    0.33,
]

ez_AC = [
    0.04,
    0.05,
    0.02,
    0.05,
    0.02,
    0.02,
    0.04,
    0.05,
    0.05,
    0.05,
    0.04,
    0.03,
    0.06,
    0.12,
    0.10,
    0.03,
    0.05,
    0.05,
]

z_BD = [
    2.61,
    0.82,
    0.41,
    2.67,
    0.35,
    0.32,
    1.87,
    1.76,
    1.15,
    1.06,
    0.83,
    0.31,
    0.58,
    2.35,
    2.16,
    0.30,
    0.30,
    0.34,
]
ez_BD = [
    0.03,
    0.04,
    0.02,
    0.04,
    0.02,
    0.01,
    0.04,
    0.09,
    0.04,
    0.04,
    0.06,
    0.02,
    0.04,
    0.10,
    0.08,
    0.03,
    0.04,
    0.02,
]
z_old = [
    3.00,
    0.87,
    0.40,
    2.55,
    0.18,
    0.36,
    2.25,
    2.15,
    1.25,
    1.25,
    0.88,
    0.23,
    0.46,
    2.30,
    2.01,
    0.27,
    0.30,
    0.27,
]
ez_old = [
    0.10,
    0.17,
    0.10,
    0.15,
    0.07,
    0.05,
    0.15,
    0.15,
    0.05,
    0.05,
    0.17,
    0.08,
    0.15,
    0.23,
    0.13,
    0.13,
    0.10,
    0.13,
]

# %%
fig, ax = plt.subplots(figsize=(7, 6))
ax.errorbar(z_BD, z_old, xerr=ez_BD, yerr=ez_old, fmt="o", capsize=3)
ax.set_xlabel(r"$z_{BD}$ (mm)")
ax.set_ylabel(r"$z_{old}$ (mm)")
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)
ax.plot([0, 4], [0, 4], ls="--", c="k")

# %%
fig, ax = plt.subplots(figsize=(7, 6))
ax.errorbar(z_BD, z_old, xerr=ez_BD, yerr=ez_old, fmt="o", capsize=3)
ax.set_xlabel(r"$z_{BD}$ (mm)")
ax.set_ylabel(r"$z_{old}$ (mm)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(0.1, 10)
ax.set_ylim(0.1, 10)
ax.plot([0, 10], [0, 10], ls="--", c="k")

# %%
fig, ax = plt.subplots(figsize=(7, 6))
ax.errorbar(z_BD, z_AC, xerr=ez_BD, yerr=ez_AC, fmt="o", capsize=3)
ax.set_xlabel(r"$z_{BD}$ (mm)")
ax.set_ylabel(r"$z_{AC}$ (mm)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(0.1, 10)
ax.set_ylim(0.1, 10)
ax.plot([0, 10], [0, 10], ls="--", c="k")

# %%
fig, ax = plt.subplots(figsize=(7, 6))
ax.errorbar(z_BD, z_AC, xerr=ez_BD, yerr=ez_AC, fmt="o", capsize=3)
ax.set_xlabel(r"$z_{BD}$ (mm)")
ax.set_ylabel(r"$z_{AC}$ (mm)")
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)
ax.plot([0, 4], [0, 4], ls="--", c="k")

# %%
systematic = 0.1
total_uncertainty = np.sqrt((np.array(z_BD) * systematic) ** 2 + (np.array(ez_BD)) ** 2)

# %%
total_uncertainty
# Out:
# array([0.26271848, 0.09123596, 0.04561798, 0.26997963, 0.04031129,
#        0.03352611, 0.12175796, 0.19123023, 0.1976765 , 0.05      ])
